# %% [markdown]
# <a href="https://colab.research.google.com/github/HsiuuYing/python-machine-learning/blob/main/%E5%B0%88%E9%A1%8C%E4%B8%80_Medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-97cb1544-6a81-4aaf-b048-5a712d0d4be4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97cb1544-6a81-4aaf-b048-5a712d0d4be4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sampleSubmission.csv to sampleSubmission.csv
# Saving test.csv to test.csv
# Saving train.csv to train.csv

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
submit = pd.read_csv('sampleSubmission.csv')

print( f'train {df_train.shape}' )
display( df_train.head() ) 

print( f'\ntest {df_test.shape}' )
display( df_test.head() )
# Out:
# train (10886, 12)
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1
# test (6493, 9)
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# ...

# %%
bike = pd.read_csv('train.csv')

# %%
bike
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
X = bike[['holiday', 'workingday', 'weather']]
y = bike['season']
X['workingday'] = X['workingday'].fillna(X['workingday'].mean())

# %%
X_train['weather'] = X_train['weather'].map({'1':0,'2':1})
X_test['weather'] = X_test['weather'].map({'1':0,'2':1})
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-33b005be7c1a> in <module>()
# ----> 1 X_train['weather'] = X_train['weather'].map({'1':0,'2':1})
#       2 X_test['weather'] = X_test['weather'].map({'1':0,'2':1})
#       3 X_train
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# **分割**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.6,test_size=0.2)
X_train

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test, y_test))
from xgboost import XGBClassifier
xgbc = XGBClassifier()
xgbc.fit(X_train, y_train)
print('The accuracy of eXtreme Gradient Boosting Classifier on testing set:', xgbc.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7128a3bb985b> in <module>()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier()
# ----> 3 rfc.fit(X_train, y_train)
#       4 print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test, y_test))
#       5 from xgboost import XGBClassifier
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier
knnModel = KNeighborsClassifier(n_neighbors=3)
knnModel.fit(X_train,y_train)
predicted = knnModel.predict(X_train)
print('訓練集: ',knnModel.score(X_train,y_train))
print('測試集: ',knnModel.score(X_test,y_test))

# %%
from sklearn import tree
from sklearn import datasets
import pydotplus
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.6,test_size=0.2)
clf=tree.DecisionTreeClassifier(criterion='gini',max_depth=3).fit(X_train,y_train)
clf.predict(X_test)
clf.score(X_test,y_test)

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion = 'entropy', random_state=0)
tree.fit(X_train,y_train)
tree.predict(X_test)
